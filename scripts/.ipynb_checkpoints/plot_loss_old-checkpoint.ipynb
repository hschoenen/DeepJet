# %% [markdown]
# # Loss curves
# ## Comparison of different trainings via train & val loss

# %%
import numpy as np

import matplotlib.pyplot as plt
import mplhep as hep

plt.style.use(hep.cms.style.ROOT)

# %%
model_names = ['nominal', 'adversarial','adversarial_flavour_008009010']#,'adversarial_flavour_006008010']#,'adversarial_flavour_010009010']

# %%
models_str = 'models'

# %%
tagger = 'DF_Run2'

# %%
dirz = {
    'nominal': f'/eos/user/h/heschone/DeepJet/Train_DF_Run2/nominal/',
    'adversarial': f'/eos/user/h/heschone/DeepJet/Train_DF_Run2/fgsm/',
    'adversarial_flavour_006008010': f'/eos/user/h/heschone/DeepJet/Train_DF_Run2/fgsm_flavour_006008010/',
    'adversarial_flavour_008009010': f'/eos/user/h/heschone/DeepJet/Train_DF_Run2/fgsm_flavour_008009010/',
    'adversarial_flavour_010009010': f'/eos/user/h/heschone/DeepJet/Train_DF_Run2/fgsm_flavour_010009010/'
}
save_dir = f'/eos/user/h/heschone/DeepJet/Plots/'

# %%
colorcode = ['darkblue', 'royalblue', 'saddlebrown', 'orange', 'forestgreen', 'limegreen', 'purple', 'magenta']
colors = {
    'nominal' : ['darkblue', 'royalblue'],
    'adversarial' : ['saddlebrown', 'orange'],
    'adversarial_flavour_006008010': ['forestgreen', 'limegreen'],
    'adversarial_flavour_008009010': ['purple', 'magenta'],
    'adversarial_flavour_010009010': ['darkred', 'red']
    }

# %%
paths = {
    'nominal' : dirz['nominal'] + f'loss_trainval.npy',
    'adversarial' : dirz['adversarial'] + f'loss_trainval.npy',
    'adversarial_flavour_006008010': dirz['adversarial_flavour_006008010'] + f'loss_trainval.npy',
    'adversarial_flavour_008009010': dirz['adversarial_flavour_008009010'] + f'loss_trainval.npy',
    'adversarial_flavour_010009010': dirz['adversarial_flavour_010009010'] + f'loss_trainval.npy',
    }

# %%
leg_text = {
    'nominal' : 'nominal, bsize=4000',
    'adversarial' : r'adversarial ($\epsilon=0.01$, bsize=4000)',
    'adversarial_flavour_006008010': r'adversarial ($\epsilon=(0.006,0.008,0.01)$, bsize=4000)',
    'adversarial_flavour_008009010': r'adversarial ($\epsilon=(0.008,0.009,0.01)$, bsize=4000)',
    'adversarial_flavour_010009010': r'adversarial ($\epsilon=(0.01,0.009,0.01)$, bsize=4000)',
    }

# %%
plt.figure(1,figsize=[13,10])
plt.grid(which='minor', alpha=0.85)
plt.grid(which='major', alpha=0.95, color='black')
for model in model_names:
    train_val_loss = np.load(paths[model])
    n_epochs = len(train_val_loss[0])
    epoch_axis = np.arange(1,n_epochs+1)
    # plot training loss
    plt.plot(epoch_axis, train_val_loss[0], color=colors[model][0], label=f'Training loss ({leg_text[model]})')
    # plot validation loss
    plt.plot(epoch_axis, train_val_loss[1], color=colors[model][1], label=f'Validation loss ({leg_text[model]})')
plt.xlabel('epoch')
plt.ylabel('loss')
leg = plt.legend(fontsize=16)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)
plt.savefig('train_val_loss_' + tagger + '_' + models_str + '.pdf', bbox_inches='tight')
plt.savefig(save_dir + 'train_val_loss_' + tagger + '_' + models_str + '.pdf', bbox_inches='tight')

# %%
plt.figure(1,figsize=[13,10])
plt.grid(which='minor', alpha=0.85)
plt.grid(which='major', alpha=0.95, color='black')
for model in model_names:
    train_val_loss = np.load(paths[model])
    n_epochs = len(train_val_loss[0])
    epoch_axis = np.arange(1,n_epochs+1)
    # plot training loss
    plt.plot(epoch_axis, train_val_loss[0], color=colors[model][0], label=f'Training loss ({leg_text[model]})')
    # plot validation loss
    #plt.plot(epoch_axis, train_val_loss[1], color=colors[model][1], label=f'Validation loss ({leg_text[model]})')
plt.xlabel('epoch')
plt.ylabel('loss')
leg = plt.legend(fontsize=16)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)
plt.savefig('train_loss_' + tagger + '_' + models_str + '.pdf', bbox_inches='tight')
plt.savefig(save_dir + 'train_loss_' + tagger + '_' + models_str + '.pdf', bbox_inches='tight')

# %%
plt.figure(1,figsize=[13,10])
plt.grid(which='minor', alpha=0.85)
plt.grid(which='major', alpha=0.95, color='black')
for model in model_names:
    train_val_loss = np.load(paths[model])
    n_epochs = len(train_val_loss[0])
    epoch_axis = np.arange(1,n_epochs+1)
    # plot training loss
    #plt.plot(epoch_axis, train_val_loss[0], color=colors[model][0], label=f'Training loss ({leg_text[model]})')
    # plot validation loss
    plt.plot(epoch_axis, train_val_loss[1], color=colors[model][1], label=f'Validation loss ({leg_text[model]})')
plt.xlabel('epoch')
plt.ylabel('loss')
leg = plt.legend(fontsize=16)
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(3.0)
plt.savefig('train_loss_' + tagger + '_' + models_str + '.pdf', bbox_inches='tight')
plt.savefig(save_dir + 'train_loss_' + tagger + '_' + models_str + '.pdf', bbox_inches='tight')
